# %% [markdown]
# # Inference using a Conditional Diffusion Model

# %% [markdown]
# In this notebook we show how to perform inference using GT4SD and the models implemented in Diffusers. The first time you run this cell a bunch of tokenizers, encoders, unet models will be downloaded.

# %%
from gt4sd.algorithms.registry import ApplicationsRegistry

algorithm = ApplicationsRegistry.get_application_instance(
    target=None,
    algorithm_type='generation',
    domain='generic',
    algorithm_name='DiffusersGenerationAlgorithm',
    algorithm_application='LDMTextToImageGenerator', # you will need to authenticate in hf
    # include additional configuration parameters as **kwargs
)
# Out:
# NOTE: Redirects are currently not supported in Windows or MacOs.
# Using TensorFlow backend.
# INFO:toxsmi.utils.wrappers:Class weights are (1, 1).
# 16:21:24   Class weights are (1, 1).
# INFO:toxsmi.utils.wrappers:Class weights are (1, 1).
# 16:21:24   Class weights are (1, 1).
# INFO:tape.models.modeling_utils:Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex .
# 16:21:25   Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex .
# INFO:gt4sd.algorithms.core:runnning DiffusersGenerationAlgorithm with configuration=LDMTextToImageGenerator(algorithm_version='CompVis/ldm-text2im-large-256', modality='token2image', model_type='latent_diffusion_conditional', scheduler_type='discrete', temperature=1.0, repetition_penalty=1.0, k=50, p=1.0, prefix='', number_of_sequences=8)
# ...

# %%
prompt = "Logo for GT4SD"
image = algorithm.generator(prompt=prompt)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
image[0]
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FE3AACDC190>

# %%
prompt = "GT4SD on the moon!"
image = algorithm.generator(prompt=prompt)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
image[0]
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FE3AADF0F50>

# %%
prompt = "Generative Models for Scientific Discovery"
image = algorithm.generator(prompt=prompt)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
image[0]
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7FE3AADF0F10>
